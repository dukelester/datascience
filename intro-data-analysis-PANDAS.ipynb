# %%
import pandas as pd

#data frame

# %%
president_df = pd.read_csv('president.csv')
president_df
# Out:
#       year    state state_po  state_fips  state_cen  state_ic        office  \
# 0     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 1     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 2     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 3     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 4     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# ...    ...      ...      ...         ...        ...       ...           ...
# 4282  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4283  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4284  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4285  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4286  2020  WYOMING       WY          56         83        68  US PRESIDENT
#
# ...

# %%
president_df = pd.read_csv('president.csv')
type(president_df)
president_df.info()
president_df.describe() 
#columns
president_df.columns
president_df.shape

votes = president_df['candidatevotes']
type(votes)
votes[200]
president_df[['candidate', 'candidatevotes']]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4287 entries, 0 to 4286
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   year              4287 non-null   int64
#  1   state             4287 non-null   object
#  2   state_po          4287 non-null   object
#  3   state_fips        4287 non-null   int64
#  4   state_cen         4287 non-null   int64
#  5   state_ic          4287 non-null   int64
#  6   office            4287 non-null   object
#  7   candidate         4000 non-null   object
#  8   party_detailed    3831 non-null   object
#  9   writein           4284 non-null   object
#  10  candidatevotes    4287 non-null   int64
#  11  totalvotes        4287 non-null   int64
#  12  version           4287 non-null   int64
#  13  notes             0 non-null      float64
#  14  party_simplified  4287 non-null   object
# dtypes: float64(1), int64(7), object(7)
# memory usage: 502.5+ KB
# ...

# %%
#creating a copy of a file
president_copy = president_df.copy()
president_copy
# Out:
#       year    state state_po  state_fips  state_cen  state_ic        office  \
# 0     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 1     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 2     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 3     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 4     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# ...    ...      ...      ...         ...        ...       ...           ...
# 4282  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4283  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4284  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4285  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4286  2020  WYOMING       WY          56         83        68  US PRESIDENT
#
# ...

# %%
#accessing rows
#.loc using the indexing notation

president_copy.loc[4285]
president_copy.loc[[4282, 4284, 4285, 4280]]
president_copy.head(200)
president_copy.tail(20)

president_copy['notes']
president_copy.at[0,'notes']
type(president_copy.at[0,'notes'])
president_copy.sample(23)
newdata = president_copy.sample(90)
newdata.describe()
newdata.totalvotes.cumsum()
newdata.totalvotes.cumprod()
newdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90 entries, 3878 to 1171
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   year              90 non-null     int64
#  1   state             90 non-null     object
#  2   state_po          90 non-null     object
#  3   state_fips        90 non-null     int64
#  4   state_cen         90 non-null     int64
#  5   state_ic          90 non-null     int64
#  6   office            90 non-null     object
#  7   candidate         84 non-null     object
#  8   party_detailed    85 non-null     object
#  9   writein           90 non-null     object
#  10  candidatevotes    90 non-null     int64
#  11  totalvotes        90 non-null     int64
#  12  version           90 non-null     int64
#  13  notes             0 non-null      float64
#  14  party_simplified  90 non-null     object
# dtypes: float64(1), int64(7), object(7)
# memory usage: 11.2+ KB

# %%
from IPython.display import display
with pd.option_context('display.max_rows', 42): #display 3000 rows
    display(president_copy[president_copy.candidatevotes>100000])
    
    president_copy = president_copy[president_copy.totalvotes / president_copy.candidatevotes > 5]
    canditate_ratio
ratio = president_copy.totalvotes / president_copy.candidatevotes 
ratio > 5.990

# canditate_ratio

#add the ratio to the data
# president_copy['ratio'] = canditate_ratio
president_copy
president_copy['candidate_ratio'] = round(president_copy.totalvotes / president_copy.candidatevotes)
president_copy

#sort the data

president_copy.sort_values('totalvotes', ascending=False).tail(90)
president_copy.at[93, 'notes'] = 454
president_copy.at[93, 'notes'] 

president_copy.at[205, 'notes'] = 90

# converting version to date
president_copy.version = pd.to_datetime(president_copy.version)
president_copy.version
# Out:
#       year       state state_po  state_fips  state_cen  state_ic  \
# 205   1976    NEW YORK       NY          36         21        13
# 206   1976    NEW YORK       NY          36         21        13
# 207   1976    NEW YORK       NY          36         21        13
# 364   1980  CALIFORNIA       CA           6         93        71
# 365   1980  CALIFORNIA       CA           6         93        71
# ...    ...         ...      ...         ...        ...       ...
# 3712  2016  WASHINGTON       WA          53         91        73
# 3713  2016  WASHINGTON       WA          53         91        73
# 3725  2016   WISCONSIN       WI          55         35        25
# 3775  2020  CALIFORNIA       CA           6         93        71
# 4203  2020       TEXAS       TX          48         74        49
#
#             office             candidate party_detailed writein  ...  \
# 205   US PRESIDENT          FORD, GERALD   CONSERVATIVE   False  ...
# ...

# %%
#extracting the data from the date using the DatetimeIndex class

president_copy['Year'] = pd.DatetimeIndex(president_copy.version).year
president_copy['Month'] = pd.DatetimeIndex(president_copy.version).month
president_copy['Day'] = pd.DatetimeIndex(president_copy.version).day
president_copy['Weekday'] = pd.DatetimeIndex(president_copy.version).weekday


president_copy_jan = president_copy[president_copy.Month == 1]
president_copy_jan

#extract the data from the dataframe ==> candidate ==>totalvotes ==>sate_cen

president_copy_jan_matrix = president_copy_jan[['state_cen', 'candidatevotes', 'totalvotes']]
president_copy_jan_matrix                                           
president_copy_jan_matrix.sum()
# Out:
# state_cen             161935
# candidatevotes      54288207
# totalvotes        7424910519
# dtype: int64

# %%
#grouping the data

monthl_group = president_copy.groupby("Month")
monthl_group[['state_cen', 'candidatevotes', 'totalvotes']].sum()

#aggregating by mean 
president_month_mean_df = president_copy.groupby('Weekday')[['state_cen', 'candidatevotes', 'totalvotes']]
round(president_month_mean_df.mean())
president_copy.candidatevotes.cummax()

president_copy.candidatevotes.plot(title='canddate votes')
president_copy.totalvotes.plot(title='Total votes')
president_copy[['state_cen', 'candidatevotes', 'totalvotes']].plot(title='data')
uni = pd.unique(president_copy.state)
uni
names = pd.unique(president_copy.candidate)
names
# Out:
# array(['MADDOX, LESTER', 'BUBAR, BENJAMIN ""BEN""', 'HALL, GUS',
#        'MACBRIDE, ROGER', nan, 'MCCARTHY, EUGENE ""GENE""',
#        'CAMEJO, PETER', 'ANDERSON, THOMAS J.', 'WRIGHT, MARGARET',
#        'LAROUCHE, LYNDON, JR.', 'SCATTERING', 'FORD, GERALD', 'OTHER',
#        'JULIUS ""JULES"", LEVIN', 'ZEIDLER, FRANK', 'CARTER, JIMMY',
#        'ANDERSON, JOHN B.', 'RARICK, JOHN', 'CLARK, EDWARD ""ED""',
#        'DEBERRY, CLIFTON', 'MCREYNOLDS, DAVID', 'COMMONER, BARRY',
#        'GRISWOLD, DEIRDRE', 'SMITH, MAUREEN', 'PULLEY, ANDREW',
#        'GREAVES, PERCY L, JR.', 'REAGAN, RONALD', 'SHELTON, FRANK, JR.',
#        'MCCORMACK, ELLEN', 'LYNEN, KURT', 'GAHRES, WILLIAM ""BILL""',
#        'WENDELKEN, MARTIN E.', 'MCLAIN, HARLEY', 'CONGRESS, RICHARD',
#        'BERGLAND, DAVID', 'RICHARDS, BOB', 'MASON, MELVIN',
#        'SERRETTE, DENNIS', 'JOHNSON, SONIA', 'DODGE, EARL',
#        'LOWERY, ARTHUR', 'DENNIS, DELMAR', 'HOLMES, LARRY',
# ...
